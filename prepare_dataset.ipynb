# %%
with open("/mnt/28857F714F734EE8/quan_tran/ops/class/hierarchy.txt", "r") as f:
    contents = f.read().splitlines()
content = {}
for i in contents:
    pa, ch = i.split()
    if ch not in content:
        content[ch] = pa
    else:
        old_pa = content[ch]
        if old_pa != pa:
            print(ch)
#     content += i.split()
# content = list(set(content))
# Out:
# n02430830
# n02403231
# n02472987
# n02403740
# n02403820
# n02386746
# n02376918
# n02090827
# n02503517
# n02121808
# n02384741
# n02084071
# n01323068
# n01862399
# n01322508
# n01322898
# n01322983
# n01322604
# n02672831
# n03140771
# n04308273
# n02867715
# n04308397
# n03335030
# n04062644
# n04552348
# n04264914
# n04208760
# n04487894
# n04552696
# n03478589
# n03919096
# n04062807
# n04389033
# n04389033
# n04399269
# n04566561
# n04320405
# n03773504
# n02924554
# n03769967
# n03770679
# n03445924
# n04225987
# n03776460
# n04576211
# n03201035
# n03982430
# n02803934
# n07739125
# n07743902
# n07744811
# n07745466
# n07751004
# n07751451
# n07757132
# n07765208
# n07765999
# n07767847
# n07769584
# n07705931
# n07750586
# n07767344
# n01401106
# n02804123
# n02804252
# n02867267
# n04376400
# n03038870
# n03039015
# n03854065
# n03928116
# n03928116
# n11530008
# n12144399
# n11672400
# n12956170
# n11747468
# n12942025
# n13084834
# n11729478
# n11856055
# n12711817
# ...

# %%
len(content)
# Out:
# 74401

# %%
with open("/mnt/28857F714F734EE8/quan_tran/ops/class/id_to_name.txt", "r") as f:
    contents_name = f.read().splitlines()
content_name = [i.split()[0] for i in contents_name]
content_name = list(set(content_name))

# %%
a = {1:{1,3,4}}
a.get(1)
# Out:
# {1, 3, 4}

# %%
a = {1,3}
a.add(1)
a
# Out:
# {1, 3}

# %%
for i in content:
    if i not in content_name:
        print(i)
